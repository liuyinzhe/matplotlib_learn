# %%
import matplotlib.pyplot as plt
import numpy as np

# 0.05 到 10 之间均匀地取1000个数字
x = np.linspace(0.05,10,1000) 
# cos 函数
y = np.cos(x) 

plt.plot(x,y,ls="-",lw=2,label = "plot figure")
plt.legend()
plt.show()

# %% [markdown]
# ### 1.3.1  函数 plot() 展示变量的趋势变化
#
# #### 调用签名 plt.plot(x,y,ls="-",lw=2,label = "plot figure")
# * x: x轴上的数值
# * y: y轴上的数值
# * ls: 折线图的线条风格  linestyle or ls {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
# * lw: 折线图的线条宽度  linewidth or lw float
# * label: 标记图形内容的标签文本
#
# |线型|描述|
# |----|----|
# |'-' 或者 'solid'|实线|
# |'--' 或者 'dashed'|虚线|
# |'-.' 或者 'dashdot'|点划线|
# |':' 或者 'dotted'|虚线|
# |'None'或或' '''|什么也不画|
#
# 其他形式 (offset, onoffseq) 参考 set_dashes()
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D.set_linestyle
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html?highlight=plot#matplotlib.pyplot.plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# 0.05 到 10 之间均匀地取1000个数字
x = np.linspace(0.05,10,1000) 
# 标准正态分布[0-1]中随机取1000个数字
#y = np.random.randn(1000)
# 在均匀分布[0-1]中随机取1000个数字
y = np.random.rand(1000)

plt.scatter(x,y,c="b",label="scatter figure")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 1.3.2  函数 scatter() 寻找变量之间的关系
#
# #### 调用签名 plt.scatter(x,y,c="b",label="scatter figure")
# * x: x轴上的数值
# * y: y轴上的数值
# * c: 散点图上标记的颜色
# * label: 标记图形内容的标签文本
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html?highlight=scatter#matplotlib.pyplot.scatter

# %%
import matplotlib.pyplot as plt
import numpy as np

# 0.05 到 10 之间均匀地取1000个数字
x = np.linspace(0.05,10,1000) 
# 标准正态分布[0-1]中随机取1000个数字
#y = np.random.randn(1000)
# 在均匀分布[0-1]中随机取1000个数字
y = np.random.rand(1000)

plt.scatter(x,y,c="b",label="scatter figure")
plt.legend()
#设置x,y轴范围
plt.xlim(0.05,10)
plt.ylim(0,1)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 1.3.3  函数 mlim() 设置x轴的数值显示范围
#
# ### 调用签名 plt.xlim(min,max)
# * min: x轴上的最小值
# * max: x轴上的最大值
# * 平移性:上面的函数功能调用方式参数说明同样可以平移到函数ylim()上

# %%
import matplotlib.pyplot as plt
import numpy as np


# 0.05 到 10 之间均匀地取1000个数字
x = np.linspace(0.05,10,1000) 
# sin 函数
y = np.sin(x) 

plt.plot(x,y,ls="-.",lw=2,c="c",label="scatter figure")
plt.legend()

# x,y轴标签
plt.xlabel("x-axis")
plt.ylabel("y-axis",loc='center')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 1.3.4  函数 xlabel() 设置x轴的标签文本
#
# #### 调用签名 plt.xlabel(string)
# * string: 标签文本内容
# * loc: 标签文本位置{'bottom', 'center', 'top'}
# * 平移性: 上面的函数功能调用方式参数说明同样可以平移到函数ylabel()上
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlabel.html
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.ylabel.html

# %%
import matplotlib.pyplot as plt
import numpy as np


# 0.05 到 10 之间均匀地取1000个数字
x = np.linspace(0.05,10,1000) 
# sin 函数
y = np.sin(x) 

plt.plot(x,y,ls="-.",lw=2,c="c",label="scatter figure")
plt.legend()

# 网格线
plt.grid(linestyle=":",color="r")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 1.3.5  函数 grid() 绘制刻度线的网格线
#
# #### 调用签名 plt.grid(linestyle=":",color="r")
# * linestyle: 网格线的线条风格
# * color: 网格线的线条颜色
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.grid.html?highlight=grid#matplotlib.pyplot.grid

# %%
import matplotlib.pyplot as plt
import numpy as np


# 0.05 到 10 之间均匀地取1000个数字
x = np.linspace(0.05,10,1000) 
# sin 函数
y = np.sin(x) 

plt.plot(x,y,ls="-.",lw=2,c="c",label="scatter figure")
plt.legend()

# 参考线
plt.axhline(y=0.0,c="r",ls="--",lw=2)
plt.axvline(x=4.0,c="r",ls="--",lw=2)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 1.3.6  函数 axhline() 绘制平行于x轴的水平参考线
#
# #### 调用签名 plt.axhline(y=0.0,c="r",ls="--",lw=2)
# * x: 水平参考线的出发点
# * c: 参考线的颜色
# * ls: 参考线的线条风格  linestyle or ls {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
# * lw: 参考线的线条宽度  linewidth or lw float
# * 平移性:上面的函数功能,调用方式和参数说明同样可以平移到函数axvline()上
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.axhline.html?highlight=axhline#matplotlib.pyplot.axhline
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.axhline.html?highlight=axhline#matplotlib.pyplot.axvline

# %%
import matplotlib.pyplot as plt
import numpy as np


# 0.05 到 10 之间均匀地取1000个数字
x = np.linspace(0.05,10,1000) 
# sin 函数
y = np.sin(x) 

plt.plot(x,y,ls="-.",lw=2,c="c",label="scatter figure")
plt.legend()

# 参考区域
plt.axvspan(xmin=4.0,xmax=6.0,facecolor="y",alpha=0.3)
plt.axhspan(ymin=0.0,ymax=0.5,facecolor="y",alpha=0.3)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 1.3.7  函数 axvspan() 绘制垂直于x轴的参考区域
#
# #### 调用签名 plt.axvspan(xmin=1.0,xmax=2.0,facecolor="y",alpha=0.3)
# * xmin: 参考区域的起始位置
# * xmax: 参考区域的终止位置
# * facecolor: 参考区域的填充颜色
# * alpha: 参考区域的填充颜色的透明度
# * 平移性:上面的函数功能,调用方式和参数说明同样可以平移到函数axvline()上
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.axvspan.html?highlight=axvspan#matplotlib.pyplot.axvspan
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.axvspan.html?highlight=axvspan#matplotlib.pyplot.axhspan

# %%
import matplotlib.pyplot as plt
import numpy as np


# 0.05 到 10 之间均匀地取1000个数字
x = np.linspace(0.05,10,1000) 
# sin 函数
y = np.sin(x) 

plt.plot(x,y,ls="-.",lw=2,c="c",label="scatter figure")
plt.legend()

# 指向型注释文本
plt.annotate("maximum",
             xy=(np.pi/2,1.0),
             xytext=((np.pi/2)+1.0,.8),
             weight="bold",
             color="b",
             arrowprops=dict(arrowstyle="->",connectionstyle="arc3",color="b"))

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 1.3.8  函数 annotate() 添加推行内容细节的指向型注释文本
#
# #### 调用签名 plt.annotate(string,xy=(np.pi/2,1.0),xytext=((np.pi/2)+0.15,1.5),weight="bold",color="r",arrowprops=dict(arrowstyle="->",connectionstyle="arc3",color="b"))
# * string: 图形内容的注释文本
# * xy: 被注释图形内容的位置坐标
# * xytext: 注释文本的位置坐标
# * weight: 注释文本的文字粗细风格
# * color: 注释文本的字体颜色
# * arrowprops: 指示被注释内容的箭头的属性字典
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.annotate.html?highlight=annotate#matplotlib.pyplot.annotate

# %%
import matplotlib.pyplot as plt
import numpy as np


# 0.05 到 10 之间均匀地取1000个数字
x = np.linspace(0.05,10,1000) 
# sin 函数
y = np.sin(x) 

plt.plot(x,y,ls="-.",lw=2,c="c",label="scatter figure")
plt.legend()

# 无指向型注释文本
plt.text(3.10,0.09,"y=sin(x)",weight="bold",color="b")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 1.3.9  函数 text() 添加图形内容细节的无指向型注释文本
#
# #### 调用签名 plt.text(x,y,string,weight="bold",color="r")
# * x: 注释文本内容所在位置的横坐标
# * y: 注释文本内容所在位置的纵坐标
# * string: 注释文本内容
# * fontsize or size: 注释文本的字体大小 # float or {'xx-small', 'x-small', 'small', 'medium', 'large', 'x-large', 'xx-large'}
# * weight: 注释文本的文字粗细风格 fontweight or weight
# * color: 注释文本的字体颜色
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.text.html?highlight=text#matplotlib.pyplot.text

# %%
import matplotlib.pyplot as plt
import numpy as np


# 0.05 到 10 之间均匀地取1000个数字
x = np.linspace(0.05,10,1000) 
# sin 函数
y = np.sin(x) 

plt.plot(x,y,ls="-.",lw=2,c="c",label="scatter figure")
plt.legend()

# 标题
plt.title("y=sin(x)")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 1.3.10  函数 title() 添加图形内容的标题
#
# #### 调用签名 plt.title(string)
# * string: 图形内容的标题文本
# * loc : 注释文本的位置 # {'center', 'left', 'right'},
# * fontdict: 注释文本的字体格式字典
#
# {'fontsize': rcParams['axes.titlesize'],
#  'fontweight': rcParams['axes.titleweight'],
#  'color': rcParams['axes.titlecolor'],
#  'verticalalignment': 'baseline',
#  'horizontalalignment': loc}
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.title.html?highlight=title

# %%
import matplotlib.pyplot as plt
import numpy as np


# 0.05 到 10 之间均匀地取1000个数字
x = np.linspace(0.05,10,1000) 
# sin 函数
y = np.sin(x) 

plt.plot(x,y,ls="-.",lw=2,c="c",label="scatter figure")

plt.legend(loc="lower left")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 1.3.11  函数 legend() 标示不同图形的文本标签图例
#
# #### 调用签名 plt.legend(loc="lower left")
# * loc : 注释文本的位置 # {'center', 'left', 'right'},
#
# The location of the legend.
#
# The strings 'upper left', 'upper right', 'lower left', 'lower right' place the legend at the corresponding corner of the axes/figure.
#
# The strings 'upper center', 'lower center', 'center left', 'center right' place the legend at the center of the corresponding edge of the axes/figure.
#
# The string 'center' places the legend at the center of the axes/figure.
#
# The string 'best' places the legend at the location, among the nine locations defined so far, with the minimum overlap with other drawn artists. This option can be quite slow for plots with large amounts of data; your plotting speed may benefit from providing a specific location.
#
# The location can also be a 2-tuple giving the coordinates of the lower-left corner of the legend in axes coordinates (in which case bbox_to_anchor will be ignored).
#
# For back-compatibility, 'center right' (but no other location) can also be spelled 'right', and each "string" locations can also be given as a numeric value:
#
# |Location String|Location Code|
# |----|----|
# |'best'|0|
# |'upper right'|1|
# |'upper left'|2|
# |'lower left'|3|
# |'lower right'|4|
# |'right'|5|
# |'center left'|6|
# |'center right'|7|
# |'lower center'|8|
# |'upper center'|9|
# |'center'|10|
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html?highlight=legend#matplotlib.pyplot.legend

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib import cm as cm

#define data
x=np.linspace(0.5, 3.5, 100)
y=np.sin(x)
y1=np.random.randn(100)

#scatter figure
plt.scatter(x, y1, c='0.25', label='scatter figure')

#plot figure
plt.plot(x, y, ls='--', lw=2, label='plot figure')

#some clean up
#去掉上边框和右边框
for spine in plt.gca().spines.keys():
    if spine=='top' or spine=='right':
        plt.gca().spines[spine].set_color('none')
        
# x轴的刻度在下边框        
plt.gca().xaxis.set_ticks_position('bottom')

# y轴的刻度在左边框
plt.gca().yaxis.set_ticks_position('left')

#设置x轴、y轴范围
plt.xlim(0.0, 4.0)
plt.ylim(-3.0, 3.0)

#设置x轴、y轴标签
plt.xlabel('x_axis')
plt.ylabel('y_axis')

#绘制x、y轴网格
plt.grid(True, ls=':', color='r')

#绘制水平参考线
plt.axhline(y=0.0, c='r', ls='--', lw=2)

#绘制垂直参考区域
plt.axvspan(xmin=1.0, xmax=2.0, facecolor='y', alpha=0.5)

#绘制注解
plt.annotate('maximum', xy=(np.pi/2, 1.0), xytext=((np.pi/2)+0.15, 1.5), 
             weight='bold', color='r', arrowprops=dict(arrowstyle='->', 
             connectionstyle='arc3', color='r'))

#绘制注解
plt.annotate('spines', xy=(0.75, -3), xytext=(0.35, -2.25), 
             weight='bold', color='r', arrowprops=dict(arrowstyle='->', 
             connectionstyle='arc3', color='r'))

#绘制注解
plt.annotate('', xy=(0, -2.78), xytext=(0.4, -2.32), 
             weight='bold', color='r', arrowprops=dict(arrowstyle='->', 
             connectionstyle='arc3', color='r'))

#绘制注解
plt.annotate('', xy=(3.5, -2.98), xytext=(3.6, -2.7), 
             weight='bold', color='r', arrowprops=dict(arrowstyle='->', 
             connectionstyle='arc3', color='r'))

#绘制文本
plt.text(3.6, -2.70, "'|' is tickline", weight='bold', color='b')
plt.text(3.6, -2.95, "3.5 is tickline", weight='bold', color='b')


plt.title("structure of matplotlib")

plt.legend(loc='upper right')

plt.show()
